# %%
class Node:
    def __init__(self,element,next):
        self.element=element
        self.next=next
        

class MyList:                         
    def __init__(self,a):
        self.head=None
        tail=None
        for i in a:
            n=Node(i,None)
            if self.head==None:
                self.head=n
                tail=n
            else:
                tail.next=n
                tail=n
                    
    def showList(self):
        n=self.head                      
        if n==None:
            print('Empty list')
        while n!=None:
            print(n.element)
            n=n.next
    def remove_indx(self):
        n=self.head
        count=0
        while n!=None:
            n=n.next
            count+=1
        temp=count//2
        if count==0:
            return None
        elif count==1:
            return None
        else:
            snd_indx=None
            last2nd_indx=None
            nn=self.head
            indx=0
            while nn!=None:
                if indx==1:
                    snd_indx=nn
                elif indx==count-2:
                    last2nd_indx=nn
                nn=nn.next
                indx+=1
            
            snd_indx.element,last2nd_indx.element=last2nd_indx.element,snd_indx.element
   
                  
        if count%2==0:
                temp1=self.head
                k=None
                c1=1
                l=None
                while temp1!=None:
                    if count//2==c1:
                        k=temp1
                        l=temp1.next
                    temp1=temp1.next
                    c1+=1
                k.next=l.next
        else:
            temp1=self.head
            k=None
            c1=1
            l=None
            while temp1 !=None:
                if count//2==c1:
                    k=temp1
                    l=temp1.next
                temp1=temp1.next
                c1+=1
            k.next=l.next


a=[1,2,3,4,5,6]
lst=MyList(a)
lst.remove_indx()
lst.showList()
# Out:
# 1
# 5
# 3
# 2
# 6

# %%
class Node:
    def __init__(self, e, n):
        self.element = e 
        self.next = n

class MyList:
    def __init__ (self, a):
        self.head=None
        tail=None
        for i in a:
            n=Node(i,None)
            if self.head is None:
                self.head=n
                tail=n
            else:
                tail.next=n
                tail=n

    def showList(self):
        n=self.head
        if n==None:
            print('Empty list')
        while (n is not None):
            print(n.element)
            n=n.next
    def swapDeleteMid(self):
        i=self.head
        count=0
        while i is not None:
            i=i.next
            count+=1
        if count<=1:
            print('NULL')
        else:
        #swap
            j=self.head
            count1=0
            second=None
            secondlast=None
            while j is not None:
                if count1==1:
                    second=j
                elif count1==(count-2):
                    secondlast=j
                j=j.next
                count1+=1
            second.element,secondlast.element=secondlast.element,second.element
            #delete    
            if count%2==0:
                deletekey=count//2
                n=self.head
                presentref=None
                nextref=None
                count=1
                while n is not None:
                    if deletekey==count:
                        presentref=n
                        nextref=n.next
                    n=n.next
                    count+=1
                presentref.next=nextref.next
            else:
                deletekey=count//2
                n=self.head
                presentref=None
                nextref=None
                count=1
                while n is not None:
                    if deletekey==count:
                        presentref=n
                        nextref=n.next
                    n=n.next
                    count+=1
                presentref.next=nextref.next

list1=[1,2,3,4,5,6]
list2=MyList(list1)
list2.swapDeleteMid()
list2.showList()
# Out:
# 1
# 5
# 3
# 2
# 6

# %%
class Node:
    def __init__(self,element,next):
        self.element=element
        self.next=next
        

class MyList:                         
    def __init__(self,a):
        self.head=None
        tail=None
        for i in a:
            n=Node(i,None)
            if self.head==None:
                self.head=n
                tail=n
            else:
                tail.next=n
                tail=n
                    
    def showList(self):
        n=self.head                      
        if n==None:
            print('Empty list')
        while n!=None:
            print(n.element)
            n=n.next
    def remove_indx(self):
        n=self.head
        count=0
        while n!=None:
            n=n.next
            count+=1
        temp=count//2
        if count==0:
            return None
        elif count==1:
            return None
        else:
            snd_indx=None
            last2nd_indx=None
            nn=self.head
            indx=0
            while nn!=None:
                if indx==1:
                    snd_indx=nn
                elif indx==count-2:
                    last2nd_indx=nn
                nn=nn.next
                indx+=1
            snd_indx.element,last2nd_indx.element=last2nd_indx.element,snd_indx.element
   
                  
            if count%2==0:
                temp1=self.head
                k=None
                c1=1
                l=None
                while temp1 !=None:
                    if count//2==c1:
                        k=temp1
                        l=temp1.next
                    temp1=temp1.next
                    c1+=1
                k.next=l.next
            else:
                temp1=self.head
                k=None
                c1=1
                l=None
                while temp1 !=None:
                    if count//2==c1:
                        k=temp1
                        l=temp1.next
                    temp1=temp1.next
                    c1+=1
                k.next=l.next

        
            
a=[1,2,3,4,5,6]
lst=MyList(a)
lst.remove_indx()
lst.showList()
# Out:
# 1
# 5
# 3
# 2
# 6
