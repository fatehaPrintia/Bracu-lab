# %% [markdown]
# # binary tree
# So degree of a tree must be 2 if the degree is a 2 then it is called a binary tree by 2.
# degree of a tree must be 2.
# children can be either 0,1,2 . not more than 2
# --level=depth+1
# --height=level-1

# %% [markdown]
# # DEPTH

# %%
def depth(t,v):
    if t.isRoot(v)

# %% [markdown]
# # creating a tree node class Binary tree

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
    def insert(self,arr,root,i,l):
        if i<len(arr):
            temp=Node(arr[i])
            root=temp
            self.root.left=insert(arr,self.root.left,2*i+1,l)
            self.root.right=insert(arr,self.root.right,2*i+2,l)
    def printtree(self):
        print(self.data)
        
        
root=Node(27)
root.printtree()
# Out:
# 23

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
        self.root=None
    def insert(self,arr,root,i,l):
        if i<len(arr):
            temp=Node(arr[i])
            self.root=temp
            self.root.left=self.insert(arr,self.root.left,2*i+1,l)
            self.root.right=self.insert(arr,self.root.right,2*i+2,l)
        return self.root
def priint(root):
    if root != None:
        print(root.data,end=" ")
        priint(root.left)
        
        priint(root.right)
            
arr=[1,2,3,4,5,6]      
root1=Node(arr)       

root1.insert([1,2,3,4,5,6],None,0,len(arr))
priint(root1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
##pre order traversal(root,left,right)
class newNode:
    def __init__(self, data):
        self.data = data
        self.left = self.right = None

def insert(arr, root, i, n):

    if i < n:
        temp = newNode(arr[i])
        root = temp

        root.left = insert(arr, root.left,2 * i + 1, n)
 

        root.right = insert(arr, root.right,2 * i + 2, n)
    return root
 

def priint(root):
    if root != None:
        print(root.data,end=" ")
        priint(root.left)
        
        priint(root.right)
 

arr = [1, ]
n = len(arr)
root = None
root = insert(arr, root, 0, n)
priint(root)
# Out:
# 1 2 4 5 3 6

# %%
##postorder traversal(left,right,root)
class newNode:
    def __init__(self, data):
        self.data = data
        self.left = self.right = None

def insert(arr, root, i, n):
    if i < n:
        temp = newNode(arr[i])
        root = temp
        root.left = insert(arr, root.left,2 * i + 1, n)
        root.right = insert(arr, root.right,2 * i + 2, n)
    return root
 

def priint(root):
    if root != None:
        print(root.data,end=" ")
        priint(root.left)
        priint(root.right)
        
 

arr = [1, 2, 3, 4, 5,6]
n = len(arr)
root = None
root = insert(arr, root, 0, n)
priint(root)
# Out:
# 1 2 4 5 3 6

# %%
#inorder traversal(left,root,right)
class Node:
    def __init__(self,left, data,right):
        self.left=left
        self.data = data
        self.right = right
        
class newNode:
    
    def __init__(self,arr):
        self.head=Node(None,None,None)
        
    def insert(self,arr,i,root):
        if i ==len(arr):
            return
        if root ==None:
            self.head = Node(None,arr[i],None)
            root=self.head
#             return root.data
        if (2*i)<len(arr):
            if arr[2*i]!=None:
                root.left =Node(None, arr[2*i],None)
                self.insert(arr,2*i,root.left)
            else:
                root.left=None
        else:
            root.left=None
            
        if (2*i+1)<len(arr):
            if arr[2*i+1]!=None:
                root.right =Node(None, 2*i+1,None)
                self.insert(arr,2*i+1,root.right)
            else:
                root.right=None
        else:
            root.right=None
        return self.head
 

#     def pre(self,root2):
#         print(root2.data,end=",")
#         if root2.left!=None:
#             root2.left.self.pre()
#         if root2.right!=None:
#             root2.right.self.pre()
def is_same(root1,root2):
    if root1==None and root2==None:
        return True
    else:
        if root1.value==root2.value and is_same(root1.left,root2.left) and is_same(root1.right,root2.right):
            print(root2.value)
#             print(root2.left.value)
            print(root2.right.value)
            
#                 return True
        else:
            return False
    return False


arr = [None,1, 2, 3, 4, 5,None,6]
final=newNode(arr)
print(final.insert(arr,1, None))
# final.priint()
arr1 = [None,8, 2, 3, 8, 5,None,6]
final1=newNode(arr1)
final1.insert(arr1,1, None)
pre(final1)
# Out:
# 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-5a138025dcaf> in <module>
#      66 final1=newNode(arr1)
#      67 final1.insert(arr1,1, None)
# ---> 68 pre(final1)
#
# <ipython-input-11-fff0dddc7096> in pre(root2)
#      39
#      40 def pre(root2):
# ---> 41     print(root2.data,end=",")
#      42     if root2.left!=None:
#      43         root2.left.pre()
#
# AttributeError: 'newNode' object has no attribute 'data'

# %%
class Node:
   def __init__(self, data):
      self.left = None
      self.right = None
      self.data = data

   def insert(self, data):
      if self.data:
         if data < self.data:
            if self.left is None:
               self.left = Node(data)
            else:
               self.left.insert(data)
            elif data > self.data:
               if self.right is None:
                  self.right = Node(data)
               else:
                  self.right.insert(data)
      else:
         self.data = data

   def PrintTree(self):
      if self.left:
         self.left.PrintTree()
      print( self.data)
      if self.right:
         self.right.PrintTree()

# Use the insert method to add nodes
root = Node(12)
root.insert(6)
root.insert(14)
root.insert(3)
root.PrintTree()

# %%
class Node:
    def __init__(self, data):
        self.value = data
        self.left = None
        self.right = None


class BST:
    def __init__(self, root):
        self.root = root

    def in_order(self, start, traversal):
        if start:
            traversal = self.in_order(start.left, traversal)
            traversal.append(start.value)
            traversal = self.in_order(start.right, traversal)
        return traversal


def arr_to_tree(arr, root, i, n):
    if i < n:
        temp = Node(arr[i])
        root = temp
        root.left = arr_to_tree(arr, root.left, 2*i+1, n)
        root.right = arr_to_tree(arr, root.left, 2*i+2, n)
    return root


def main():
    li = [9, 2, 7, 4, 0, 6, 8, 8, 2, 3]

    root = None
    root = arr_to_tree(li, root, 0, len(li))

    bst = BST(root)
    print(bst.in_order(root, []))


if __name__ == '__main__':
    main()

# %%
class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None

def array_to_bst(array_nums):
    if not array_nums:
        return None
    mid_num = len(array_nums)//2
    node = TreeNode(array_nums[mid_num])
    node.left = array_to_bst(array_nums[:mid_num])
    node.right = array_to_bst(array_nums[mid_num+1:])
    return node

def preOrder(node): 
    if not node: 
        return      
    print(node.val)
    preOrder(node.left) 
    preOrder(node.right)   

array_nums = [1,2,3,4,5,6,7]

print("Original array:")
print(array_nums)
result = array_to_bst(array_nums)
print("\nArray to a height balanced BST:")
print(preOrder(result))

# %%
# Python3 implementation of tree using array
# numbering starting from 0 to n-1.
tree = [None] * 10
 
 
def root(key):
    if tree[0] != None:
        print("Tree already had root")
    else:
        tree[0] = key
 
 
def set_left(key, parent):
    if tree[parent] == None:
        print("Can't set child at", (parent * 2) + 1, ", no parent found")
    else:
        tree[(parent * 2) + 1] = key
 
 
def set_right(key, parent):
    if tree[parent] == None:
        print("Can't set child at", (parent * 2) + 2, ", no parent found")
    else:
        tree[(parent * 2) + 2] = key
 
 
def print_tree():
    for i in range(10):
        if tree[i] != None:
            print(tree[i], end="")
        else:
            print("-", end="")
    print()
 
 
# Driver Code
root('A')
set_right('C', 0)
set_left('D', 1)
set_right('E', 1)
set_right('F', 2)
print_tree()
# Out:
# Can't set child at 3 , no parent found
# Can't set child at 4 , no parent found
# A-C---F---

# %%
class Node:
   def __init__(self, data):
      self.left = None
      self.right = None
      self.data = data

   def insert(self, data):
      if self.data:
         if data < self.data:
            if self.left is None:
               self.left = Node(data)
            else:
               self.left.insert(data)
            elif data > self.data:
               if self.right is None:
                  self.right = Node(data)
               else:
                  self.right.insert(data)
      else:
         self.data = data

   def PrintTree(self):
      if self.left:
         self.left.PrintTree()
      print( self.data),
      if self.right:
         self.right.PrintTree()

# Use the insert method to add nodes
root = Node(12)
root.insert(6)
root.insert(14)
root.insert(3)
root.PrintTree()

# %%
##level order traversal----> travel level wise

# %%
#inorder traversal(left,root,right)
class Node:
    def __init__(self,left, data,right):
        self.left=left
        self.data = data
        self.right = right
        
class newNode:
    
    def __init__(self,arr):
        self.head=Node(None,None,None)
        
    def insert(self,arr,i,root):
        if i ==len(arr):
            return
        if root ==None:
            self.head = Node(None,arr[i],None)
            root=self.head
            
        if (2*i)<len(arr):
            if arr[2*i]!=None:
                root.left =Node(None, arr[2*i],None)
                self.insert(arr,2*i,root.left)
            else:
                root.left=None
        else:
            root.left=None
            
        if (2*i+1)<len(arr):
            if arr[2*i+1]!=None:
                root.right =Node(None, arr[2*i+1],None)
                self.insert(arr,2*i+1,root.right)
            else:
                root.right=None
        else:
            root.right=None
 

    def priint(self,root):
        while root!=None:
            self.priint(root.data,end=" ")                            
            self.priint(root.left)
                
            self.priint(root.right)
            
arr = [None,1, 2, 3, 4, 5,None,6]
final=newNode(arr)
final.insert(arr,1, None)
final.priint(None)

# %%
#inorder traversal(left,root,right)
class Node:
    def __init__(self,left, data,right):
        self.left=left
        self.data = data
        self.right = right
        
class newNode:
    
    def __init__(self,arr):
        self.head=Node(None,None,None)
        
    def insert(self,arr,i,root):
        if i ==len(arr):
            return
        if root ==None:
            self.head = Node(None,arr[i],None)
            root=self.head
            
        if (2*i)<len(arr):
            if arr[2*i]!=None:
                root.left =Node(None, arr[2*i],None)
                self.insert(arr,2*i,root.left)
            else:
                root.left=None
        else:
            root.left=None
            
        if (2*i+1)<len(arr):
            if arr[2*i+1]!=None:
                root.right =Node(None, arr[2*i+1],None)
                self.insert(arr,2*i+1,root.right)
            else:
                root.right=None
        else:
            root.right=None
    def priint(self, root):
        if root == None:
            return
        if root.left==None:
            pass
        else:
            print(root.left.data)
        if root.right == None:
            pass
        else:
            print(root.right.data)
        self.priint(root.left)
        self.priint(root.right)
            
arr = [None,1, 2, 3, 4, 5,None,6]
final=newNode(arr)
final.insert(arr,1, None)
final.priint(final.head)
# Out:
# 2
# 3
# 4
# 5
# 6

# %%
class Node:
    def __init__(self,value):
        self.value=value
        self.left=self.right=None
        
    def insert(self,val):
        if self.value==None:
            self.value=val
            return
        if self.value==val:
            return
        if self.value>val:
            if self.left!=None:
                self.left.insert(val)
            else:
                self.left=Node(val)
        else:
            if self.right!=None:
                self.right.insert(val)
            else:
                self.right=Node(val)
                
#     def maxx(self):
#         if self.left>self.right:
#             return self.left
#         return self.right
                

    def height(self,root):
        if root==None:
            return 0
        else:
            return 1+max(self.height(root.left),self.height(root.right))
        
    def level(self):
        return 1+self.height(root1)
            
    def pre_order(self):
        print(self.value,end=",")
        if self.left!=None:
            self.left.pre_order()
        if self.right!=None:
            self.right.pre_order()
    def in_order(self):
        if self.left!=None:
            self.left.in_order()
        print(self.value,end=",")
        if self.right!=None:
            self.right.in_order()
            
    def post_order(self):
        if self.left!=None:
            self.left.post_order()
        if self.right!=None:
            self.right.post_order()
        print(self.value,end=",")
        
    def is_same(self,root1,root2):
        if root1==None and root2==None:
            return True
        else:
            if root1.value==root2.value and self.is_same(root1.left,root2.left) and self.is_same(root1.right,root2.right):
                return True
        return False
        
    def copyy(self,root2):
        




root1=Node(10)
lst=[6,3,1,6,98,3,7]
for i in lst:
    root1.insert(i)
print('The height of the tree is:',root1.height(root1))
print('The level of the tree is:',root1.level())
print("pre order traversal:")
root1.pre_order()
print()
print("In order traversal:")
root1.in_order()
print()
print("Post order traversal:")
root1.post_order()

root2=Node(10)
lst1=[6,3,1,6,98,3,7]
for i in lst1:
    root2.insert(i)
if Node.is_same(root1,root2):
    print('yes')
else:
    print("no")
    

# if root1.is_same==root2.is_same:

# %%
class Node:
    def __init__(self,left,data,right):
        self.left=left
        self.data = data
        self.right = right
class newNode:

    def __init__(self,arr):
        self.head=Node(None,None,None)

    def insert(self,arr,i,root):
        if i ==len(arr):
            return self.head
        if root ==None:
            self.head = Node(None,arr[i],None)
            print(self.head.data)
            root=self.head
            #return root.data
        if (2*i)<len(arr):
            if arr[2*i]!=None:
                root.left =Node(None, arr[2*i],None)
                self.insert(arr,2*i,root.left)
            else:
                root.left=None
        else:
            root.left=None

        if (2*i+1)<len(arr):
            if arr[2*i+1]!=None:
                root.right =Node(None, 2*i+1,None)
                self.insert(arr,2*i+1,root.right)
            else:
                root.right=None
        else:
            root.right=None
        return self.head
    
    def height(self,root):
        if root==None:
            return 0
        else:
            return 1+max(self.height(root.left),self.height(root.right))
        
    def level(self):
        return 1+self.height(root1)
    

    

def pre(root2):
        print(root2.data,end=",")
        if root2.left!=None:
            pre(root2.left)
        if root2.right!=None:
            pre(root2.right)
def is_same(root1,root2):
    if root1==None and root2==None:
        return True
    else:
        if root1.data==root2.data and is_same(root1.left,root2.left) and is_same(root1.right,root2.right):

            return True
        else:
            return False
    return False


arr = [None,1, 2, 3, 4, 5]
final=newNode(arr)
b=final.insert(arr,1, None)
print('The height of the tree is:',final.height(final1))
print('The level of the tree is:',final.level())
arr1 = [None,9, 2, 3, 8, 5,6]
final1=newNode(arr1)
a=final1.insert(arr1,1, None)
print(is_same(b,a))
pre(a)
# Out:
# 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-0a1d7dde6a3b> in <module>
#      69 final=newNode(arr)
#      70 b=final.insert(arr,1, None)
# ---> 71 print('The height of the tree is:',final.height(final1))
#      72 print('The level of the tree is:',final.level())
#      73 arr1 = [None,9, 2, 3, 8, 5,6]
#
# <ipython-input-5-0a1d7dde6a3b> in height(self, root)
#      40             return 0
#      41         else:
# ---> 42             return 1+max(self.height(root.left),self.height(root.right))
#      43
#      44     def level(self):
#
# AttributeError: 'newNode' object has no attribute 'left'

# %%
class Node:
    def __init__(self,left,data,right):
        self.left=left
        self.data = data
        self.right = right
class newNode:

    def __init__(self,arr):
        self.head=Node(None,None,None)

    def insert(self,arr,i,root):
        if i ==len(arr):
            return self.head
        if root ==None:
            self.head = Node(None,arr[i],None)
            print(self.head.data)
            root=self.head
            #return root.data
        if (2*i)<len(arr):
            if arr[2*i]!=None:
                root.left =Node(None, arr[2*i],None)
                self.insert(arr,2*i,root.left)
            else:
                root.left=None
        else:
            root.left=None

        if (2*i+1)<len(arr):
            if arr[2*i+1]!=None:
                root.right =Node(None, 2*i+1,None)
                self.insert(arr,2*i+1,root.right)
            else:
                root.right=None
        else:
            root.right=None
        return self.head
    
def height(root):
    if root==None:
        return 0
    else:
        return 1+max(height(root.left),height(root.right))
        
def level(root1):
    return 1+height(root1)
       
def pre_order(root):
    print(root.data,end=",")
    if root.left!=None:
        pre_order(root.left)
    if root.right!=None:
        pre_order(root.right)
            
def in_order(root):
    if root.left!=None:
        in_order(root.left)
    print(root.data,end=",")
    if root.right!=None:
        in_order(root.right)
            
def post_order(root):
    if root.left!=None:
        post_order(root.left)
    if root.right!=None:
        post_order(root.right)
    print(root.data,end=",")

def is_same(root1,root2):
    if root1==None and root2==None:
        return True
    else:
        if root1!=None and root2!=None:
            return root1.value==root2.value and is_same(root1.left,root2.left) and is_same(root1.right,root2.right)
    return False

def copy(root2):
    print(root2.data,end=",")
    if root2.left!=None:
        pre(root2.left)
    if root2.right!=None:
        pre(root2.right)


def pre(root2):
        print(root2.data,end=",")
        if root2.left!=None:
            pre(root2.left)
        if root2.right!=None:
            pre(root2.right)
def is_same(root1,root2):
    if root1==None and root2==None:
        return "Same"
    else:
        if root1.data==root2.data and is_same(root1.left,root2.left) and is_same(root1.right,root2.right):

            return "Same"
        else:
            return 'Different'
    return 'Different'


arr =  [None,10,6,3,1,98,7]
final=newNode(arr)
b=final.insert(arr,1, None)
print('The height of the tree is:',height(b))
print('The level of the tree is:',level(b))
print("pre order traversal:")
pre_order(b)
print()
print("In order traversal:")
in_order(b)
print()
print("Post order traversal:")
post_order(b)
arr1 = [None,9, 2, 3, 8, 5,7]
final1=newNode(arr1)
a=final1.insert(arr1,1, None)
print("Trees are:",is_same(b,a))
print()
print("Copy of new tree:")
copy(a)
# Out:
# 10
# The height of the tree is: 3
# The level of the tree is: 4
# pre order traversal:
# 10,6,1,5,3,7,
# In order traversal:
# 1,6,5,10,7,3,
# Post order traversal:
# 1,5,6,7,3,10,9
# Trees are: Different
#
# Copy of new tree:
# 9,2,8,5,3,7,

# %%
class Node:
    def __init__(self,left,data,right):
        self.left=left
        self.data = data
        self.right = right
class newNode:

    def __init__(self,arr):
        self.head=Node(None,None,None)

    def insert(self,arr,i,root):
        if i ==len(arr):
            return self.head
        if root ==None:
            self.head = Node(None,arr[i],None)
            print(self.head.data)
            root=self.head
            #return root.data
        if (2*i)<len(arr):
            if arr[2*i]!=None:
                root.left =Node(None, arr[2*i],None)
                self.insert(arr,2*i,root.left)
            else:
                root.left=None
        else:
            root.left=None

        if (2*i+1)<len(arr):
            if arr[2*i+1]!=None:
                root.right =Node(None, 2*i+1,None)
                self.insert(arr,2*i+1,root.right)
            else:
                root.right=None
        else:
            root.right=None
        return self.head
arr =  [None,10,6,3,1,98,7]
final=newNode(arr)
b=final.insert(arr,1, None)
# Out:
# 10

# %%
class Node:
    def __init__(self, data):
        self.value = data
        self.left = None
        self.right = None


class BST:
    def __init__(self, root):
        self.root = root

    def in_order(self, start, traversal):
        if start:
            traversal = self.in_order(start.left, traversal)
            traversal.append(start.value)
            traversal = self.in_order(start.right, traversal)
        return traversal
    
    def post_order(self,start,traversal):
        if start:
            traversal = self.post_order(start.left, traversal)
            traversal = self.post_order(start.right, traversal)
            traversal.append(start.value)
        return traversal
    def pre_order(self,start,traversal):
        if start:
            traversal.append(start.value)
            traversal = self.pre_order(start.left, traversal)
            traversal = self.pre_order(start.right, traversal)
            
        return traversal


def arr_to_tree(arr, root, i, n):
    if i < n:
        temp = Node(arr[i])
        root = temp
        root.left = arr_to_tree(arr, root.left, 2*i+1, n)
        root.right = arr_to_tree(arr, root.left, 2*i+2, n)
    return root


def main():
    li = [3,28,-1,5,8,16,3,9,15,4]

    root = None
    root = arr_to_tree(li, root, 0, len(li))

    bst = BST(root)
    print(bst.in_order(root, []))
    print(bst.post_order(root,[]))
    print(bst.pre_order(root,[]))


if __name__ == '__main__':
    main()
# Out:
# [9, 5, 15, 28, 4, 8, 4, 3, 16, -1, 3]
# [9, 15, 5, 4, 4, 8, 28, 16, 3, -1, 3]
# [3, 28, 5, 9, 15, 8, 4, 4, -1, 16, 3]
