# %%
#-----------------------------------------------Task 1-----------------------
# (a) Implement a recursive algorithm to find factorial of n. 
def factorial(n):
    if n==0:
        return 1
    else: 
        return n*factorial(n-1)
factorial(5)
#------------output-------------
# 120

# (b) Implement a recursive algorithm to find the n-th Fibonacci number.
def fibonacci(num):
    if num<0:
        return "Incorrect input"
    elif num==1:
        return 0
    elif num<=2:
        return 1
    else:
        return fibonacci(num-1)+fibonacci(num-2)
fibonacci(15)
#------------output-------------
# 377

# (c)Print all the elements of a given array recursively
def arr(s,i):
    if i==len(s):
        return 
    print(s[i],end=",")
    arr(s,i+1)

arr([1,2,3,4],0)
#------------output-------------

# 1,2,3,4,


## (d)
def exp(n,p):
    if p==0:
        return 1
    else:
        return n*exp(n,p-1)
    
exp(3,1)
exp(3,2)
exp(3,3)
#------------output-------------
# 27

#------------------------------Task 2-----------------------------------------------
# (a) decimal to binary
def dec_to_bin(n):
    if n>1:
        dec_to_bin(n//2)
    print(n%2,end=" ")
    
dec_to_bin(10)
#------------output-------------
# 1 0 1 0 

# (b)

class Node:
    def __init__(self,val,next):
        self.val=val
        self.next=next
    
class linked_list:
    def __init__(self,a):
        self.head=None
        tail=None
        
        for i in a:
            n=Node(i,None)
            if self.head==None:
                self.head=n
                self.tail=n
            else:
                self.tail.next=n
                self.tail=n
    def printval(self,node):
        if node==None:
            return 
        else:
            print(node.val,end=" ")
            self.printval(node.next)

a=[1,2,3,4]  
b=linked_list(a)
b.printval(b.head)
#------------output-------------
# 1 2 3 4 

# (c) reverse of linked list
class Node:
    def __init__(self,val,next):
        self.val=val
        self.next=next

class linked_list:
    def __init__(self,a):
        self.head=None
        tail=None
        for i in a:
            n=Node(i,None)
            if self.head==None:
                self.head=n
                self.tail=n
            else:
                self.tail.next=n
                self.tail=n
    def reverse_print(self,node):
        if node.next==None:
            self.head=node
            return
        else:
            self.reverse_print(node.next)
            n=node.next
            n.next=node
            node.next=None
    def printlist(self):
        n=self.head
        while n!=None:
            print(n.val)
            n=n.next
a=[1,2,3,4,5]        
b=linked_list(a)
b.reverse_print(b.head)
b.printlist()
#------------output-------------
# 5
# 4
# 3
# 2
# 1

#----------------------------------Task 3------------------------------------------------
def hocBuilder(height):
    if height==0:
        return 0
    elif height==1:
        return 8
    else:
        return 5+hocBuilder(height-1)
hocBuilder(3)
#------------output-------------
# 18

#-----------------------------------------task 5-----------------------------------------
#(a)
def showPalindrom(num10):
    if num10==0:
        return
    # print(num10)
    showPalindrom(num10-1)
    pattern(num10)
    print()
    
def pattern(num10):
    if num10==0:
        return
    pattern(num10-1)
    print(num10,end="")

showPalindrom(3)
#------------output-------------
# 1
# 12
# 123


#(b)

def rightTriangle(number1,number2):
    if number1==0:
        return
    spacePrint(number1-1)
    pattern(number2 -number1+1,1)
    print()
    rightTriangle(number1-1,number2)
    
def spacePrint(number):
    if number == 0:
        return
    print(" ", end="")
    spacePrint(number-1)

def pattern(number1,number2):
    if number1==0:
        return
    print(number2,end="")
    pattern(number1-1,number2+1)

rightTriangle(3,3)
#------------output-------------
#   1
#  12
# 123

#-----------------------------------------------task 6-------------------------------------------------------
class FinalQ: 
    
    def printt(self,array,idx): 
        if(idx<len(array)): 
            profit = self.calcProfit(array[idx]) 
            print(idx+1,".","Invesment:",array[idx],";Profit:",float(profit))
            self.printt(array,idx+1)
            
    def calcProfit(self,investment): 
        if investment==25000:
            return 0
        elif 25000<investment<=100000:
            return (45+self.calcProfit(investment-1000))
        elif 100000<investment:
            return (8+self.calcProfit(investment-100))
        

  
#Tester 
array=[25000,100000,250000,350000] 
f = FinalQ() 
f.printt(array,0)

# #------------output-------------
# 1 . Invesment: 25000 ;Profit: 0.0
# 2 . Invesment: 100000 ;Profit: 3375.0
# 3 . Invesment: 250000 ;Profit: 15375.0
# 4 . Invesment: 350000 ;Profit: 23375.0
# Out:
# 1,2,3,4,1 0 1 0 1 2 3 4 5
# 4
# 3
# 2
# 1
# 1
# 12
# 123
#   1
#  12
# 123
# 1 . Invesment: 25000 ;Profit: 0.0
# 2 . Invesment: 100000 ;Profit: 3375.0
# 3 . Invesment: 250000 ;Profit: 15375.0
# 4 . Invesment: 350000 ;Profit: 23375.0
